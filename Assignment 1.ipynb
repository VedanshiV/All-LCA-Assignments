# %%
# Assignment 1 : 
#  Write a python program to create a Dictionary, Tuple and List of students and perform the following operations on the dictionary: Add, Delete, Update.


students_dict = {1: "Rahul", 2: "Priya", 3: "Aman"}
students_tuple = ("Rahul", "Priya", "Aman")
students_list = ["Rahul", "Priya", "Aman"]

# Add
students_dict[4] = "Neha"
print("After Add:", students_dict)

# Delete
del students_dict[2]
print("After Delete:", students_dict)

# Update
students_dict[1] = "Riya"
print("After Update:", students_dict)
# Out:
# After Add: {1: 'Rahul', 2: 'Priya', 3: 'Aman', 4: 'Neha'}
# After Delete: {1: 'Rahul', 3: 'Aman', 4: 'Neha'}
# After Update: {1: 'Riya', 3: 'Aman', 4: 'Neha'}
